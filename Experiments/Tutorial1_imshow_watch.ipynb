# %%
import cv2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('watch.jpg',cv2.IMREAD_GRAYSCALE)
cv2.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8133b8344fd0> in <module>()
#       4
#       5 img = cv2.imread('watch.jpg',cv2.IMREAD_GRAYSCALE)
# ----> 6 cv2.imshow(img)
#       7 #cv2.waitKey(0)
#       8 #cv2.destroyAllWindows()
#
# TypeError: Required argument 'mat' (pos 2) not found

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('watch.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([100,200,100,100],[100,200,200,100],'c', linewidth=5)
plt.show()

# %%
ord('q')
# Out:
# 113

# %%
import numpy as np

# %%
print(np.arange(9).reshape(3,3))
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]]

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('images/watch.jpg')
mask = np.zeros(img.shape[:2],np.uint8)
print(img.shape)
#cv2.imshow(img.shape[:2])
# Out:
# (168, 300, 3)

# %%
x = np.array([[[1],[2],[3]], [[4],[5],[6]]])
x.shape
# Out:
# (2, 3, 1)

# %%
x[1:2]
# Out:
# array([[[4],
#         [5],
#         [6]]])

# %%
x[:,np.newaxis,:,:].shape
# Out:
# (2, 1, 3, 1)
